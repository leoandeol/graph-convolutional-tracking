# %%
import numpy as np

import torch 
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import alexnet

# %%
from data import VOT19
vot = VOT19()
video,boxes = vot.__getitem__(31)

# %%
from gct import GCT
gct = GCT(10)
video2 = video[:30,:,:,:]

# %%
out = gct.forward(video2[25,:,:,:],video2[15:25,:,:,:])
# Out:
# X torch.Size([1, 256, 11, 8]) Z torch.Size([10, 256, 11, 8])
# X torch.Size([1, 256, 88]) Z torch.Size([10, 256, 88])
# X^ torch.Size([1, 256, 88])
# A_1 torch.Size([880, 880])
# V_1 torch.Size([1, 256, 88])
# V_x torch.Size([1, 256, 88])
# tensor([[-203650.]], grad_fn=<MmBackward>)
# tensor([[861996.2500]], grad_fn=<MmBackward>)
# tensor([[-203792.6719]], grad_fn=<MmBackward>)
# tensor([[861482.0625]], grad_fn=<MmBackward>)
# tensor([[-203844.3750]], grad_fn=<MmBackward>)
# tensor([[861804.2500]], grad_fn=<MmBackward>)
# tensor([[-204219.5312]], grad_fn=<MmBackward>)
# tensor([[861562.2500]], grad_fn=<MmBackward>)
# tensor([[-203695.8438]], grad_fn=<MmBackward>)
# tensor([[861582.8750]], grad_fn=<MmBackward>)
# tensor([[-203690.9688]], grad_fn=<MmBackward>)
# tensor([[861219.7500]], grad_fn=<MmBackward>)
# tensor([[-203999.2344]], grad_fn=<MmBackward>)
# tensor([[861853.1875]], grad_fn=<MmBackward>)
# tensor([[-204114.2500]], grad_fn=<MmBackward>)
# tensor([[861482.5625]], grad_fn=<MmBackward>)
# tensor([[-203987.4844]], grad_fn=<MmBackward>)
# tensor([[861524.2500]], grad_fn=<MmBackward>)
# tensor([[-203959.7812]], grad_fn=<MmBackward>)
# tensor([[861769.1250]], grad_fn=<MmBackward>)
# tensor([[-203828.3750]], grad_fn=<MmBackward>)
# tensor([[861749.1250]], grad_fn=<MmBackward>)
# tensor([[-204009.0938]], grad_fn=<MmBackward>)
# tensor([[861862.5000]], grad_fn=<MmBackward>)
# tensor([[-204194.2656]], grad_fn=<MmBackward>)
# tensor([[861692.7500]], grad_fn=<MmBackward>)
# tensor([[-204092.5938]], grad_fn=<MmBackward>)
# tensor([[861862.0625]], grad_fn=<MmBackward>)
# tensor([[-204308.1875]], grad_fn=<MmBackward>)
# tensor([[861551.1250]], grad_fn=<MmBackward>)
# tensor([[-204352.7812]], grad_fn=<MmBackward>)
# tensor([[861415.1250]], grad_fn=<MmBackward>)
# tensor([[-203995.5469]], grad_fn=<MmBackward>)
# tensor([[861939.4375]], grad_fn=<MmBackward>)
# tensor([[-203862.9375]], grad_fn=<MmBackward>)
# tensor([[861590.6875]], grad_fn=<MmBackward>)
# tensor([[-204075.7812]], grad_fn=<MmBackward>)
# tensor([[861793.3750]], grad_fn=<MmBackward>)
# tensor([[-203718.9688]], grad_fn=<MmBackward>)
# tensor([[861663.0625]], grad_fn=<MmBackward>)
# tensor([[-204074.8281]], grad_fn=<MmBackward>)
# tensor([[861782.9375]], grad_fn=<MmBackward>)
# tensor([[-203779.7656]], grad_fn=<MmBackward>)
# tensor([[861855.3125]], grad_fn=<MmBackward>)
# tensor([[-203427.2344]], grad_fn=<MmBackward>)
# tensor([[861439.3125]], grad_fn=<MmBackward>)
# tensor([[-203895.5000]], grad_fn=<MmBackward>)
# tensor([[861460.8125]], grad_fn=<MmBackward>)
# tensor([[-204512.6719]], grad_fn=<MmBackward>)
# tensor([[861801.8750]], grad_fn=<MmBackward>)
# tensor([[-203954.0156]], grad_fn=<MmBackward>)
# tensor([[861067.6250]], grad_fn=<MmBackward>)
# tensor([[-204089.5469]], grad_fn=<MmBackward>)
# tensor([[861421.4375]], grad_fn=<MmBackward>)
# tensor([[-204318.4062]], grad_fn=<MmBackward>)
# tensor([[862092.5000]], grad_fn=<MmBackward>)
# tensor([[-204169.1719]], grad_fn=<MmBackward>)
# tensor([[861686.8125]], grad_fn=<MmBackward>)
# tensor([[-203832.2500]], grad_fn=<MmBackward>)
# tensor([[861712.3125]], grad_fn=<MmBackward>)
# tensor([[-204317.5469]], grad_fn=<MmBackward>)
# tensor([[861904.0625]], grad_fn=<MmBackward>)
# tensor([[-203949.3750]], grad_fn=<MmBackward>)
# tensor([[861723.5000]], grad_fn=<MmBackward>)
# tensor([[-203988.9375]], grad_fn=<MmBackward>)
# tensor([[861684.9375]], grad_fn=<MmBackward>)
# tensor([[-204130.8906]], grad_fn=<MmBackward>)
# tensor([[861876.8750]], grad_fn=<MmBackward>)
# tensor([[-203931.2656]], grad_fn=<MmBackward>)
# tensor([[861641.5000]], grad_fn=<MmBackward>)
# tensor([[-204119.4688]], grad_fn=<MmBackward>)
# tensor([[861623.9375]], grad_fn=<MmBackward>)
# tensor([[-204324.1094]], grad_fn=<MmBackward>)
# tensor([[861705.1250]], grad_fn=<MmBackward>)
# tensor([[-204083.8281]], grad_fn=<MmBackward>)
# tensor([[861335.3125]], grad_fn=<MmBackward>)
# tensor([[-203950.1875]], grad_fn=<MmBackward>)
# tensor([[861846.0625]], grad_fn=<MmBackward>)
# tensor([[-204343.1250]], grad_fn=<MmBackward>)
# tensor([[861479.0625]], grad_fn=<MmBackward>)
# tensor([[-204121.5625]], grad_fn=<MmBackward>)
# tensor([[861667.8750]], grad_fn=<MmBackward>)
# tensor([[-203705.7031]], grad_fn=<MmBackward>)
# tensor([[861416.7500]], grad_fn=<MmBackward>)
# tensor([[-204108.3438]], grad_fn=<MmBackward>)
# tensor([[861680.2500]], grad_fn=<MmBackward>)
# tensor([[-204268.5625]], grad_fn=<MmBackward>)
# tensor([[861636.3750]], grad_fn=<MmBackward>)
# tensor([[-1066832.6250]], grad_fn=<MmBackward>)
# tensor([[-52103.2734]], grad_fn=<MmBackward>)
# tensor([[-1066952.1250]], grad_fn=<MmBackward>)
# tensor([[-52661.3281]], grad_fn=<MmBackward>)
# tensor([[-1067085.2500]], grad_fn=<MmBackward>)
# tensor([[-52318.9180]], grad_fn=<MmBackward>)
# tensor([[-1067428.]], grad_fn=<MmBackward>)
# tensor([[-52565.1680]], grad_fn=<MmBackward>)
# tensor([[-1066834.6250]], grad_fn=<MmBackward>)
# tensor([[-52523.3828]], grad_fn=<MmBackward>)
# tensor([[-1066837.6250]], grad_fn=<MmBackward>)
# tensor([[-53004.3555]], grad_fn=<MmBackward>)
# tensor([[-1067233.2500]], grad_fn=<MmBackward>)
# tensor([[-52285.5977]], grad_fn=<MmBackward>)
# tensor([[-1067339.3750]], grad_fn=<MmBackward>)
# tensor([[-52677.0117]], grad_fn=<MmBackward>)
# tensor([[-1067164.2500]], grad_fn=<MmBackward>)
# tensor([[-52644.9414]], grad_fn=<MmBackward>)
# tensor([[-1067106.8750]], grad_fn=<MmBackward>)
# tensor([[-52384.0820]], grad_fn=<MmBackward>)
# tensor([[-1067021.6250]], grad_fn=<MmBackward>)
# tensor([[-52360.0469]], grad_fn=<MmBackward>)
# tensor([[-1067256.]], grad_fn=<MmBackward>)
# tensor([[-52243.9727]], grad_fn=<MmBackward>)
# tensor([[-1067372.8750]], grad_fn=<MmBackward>)
# tensor([[-52420.5898]], grad_fn=<MmBackward>)
# tensor([[-1067296.5000]], grad_fn=<MmBackward>)
# tensor([[-52259.0977]], grad_fn=<MmBackward>)
# tensor([[-1067505.]], grad_fn=<MmBackward>)
# tensor([[-52603.9570]], grad_fn=<MmBackward>)
# tensor([[-1067595.3750]], grad_fn=<MmBackward>)
# tensor([[-52745.8633]], grad_fn=<MmBackward>)
# tensor([[-1067213.5000]], grad_fn=<MmBackward>)
# tensor([[-52179.5078]], grad_fn=<MmBackward>)
# tensor([[-1067105.]], grad_fn=<MmBackward>)
# tensor([[-52525.4570]], grad_fn=<MmBackward>)
# tensor([[-1067284.1250]], grad_fn=<MmBackward>)
# tensor([[-52312.9922]], grad_fn=<MmBackward>)
# tensor([[-1066886.8750]], grad_fn=<MmBackward>)
# tensor([[-52408.2227]], grad_fn=<MmBackward>)
# tensor([[-1067210.5000]], grad_fn=<MmBackward>)
# tensor([[-52322.5195]], grad_fn=<MmBackward>)
# tensor([[-1066968.8750]], grad_fn=<MmBackward>)
# tensor([[-52233.6875]], grad_fn=<MmBackward>)
# tensor([[-1066591.2500]], grad_fn=<MmBackward>)
# tensor([[-52677.5234]], grad_fn=<MmBackward>)
# tensor([[-1067074.5000]], grad_fn=<MmBackward>)
# tensor([[-52715.9297]], grad_fn=<MmBackward>)
# tensor([[-1067718.8750]], grad_fn=<MmBackward>)
# tensor([[-52276.3867]], grad_fn=<MmBackward>)
# tensor([[-1067143.7500]], grad_fn=<MmBackward>)
# tensor([[-53104.2773]], grad_fn=<MmBackward>)
# tensor([[-1067197.8750]], grad_fn=<MmBackward>)
# tensor([[-52719.6562]], grad_fn=<MmBackward>)
# tensor([[-1067551.1250]], grad_fn=<MmBackward>)
# tensor([[-52031.4375]], grad_fn=<MmBackward>)
# tensor([[-1067363.6250]], grad_fn=<MmBackward>)
# tensor([[-52433.9727]], grad_fn=<MmBackward>)
# tensor([[-1067040.5000]], grad_fn=<MmBackward>)
# tensor([[-52398.8633]], grad_fn=<MmBackward>)
# tensor([[-1067487.2500]], grad_fn=<MmBackward>)
# tensor([[-52216.5234]], grad_fn=<MmBackward>)
# tensor([[-1067130.2500]], grad_fn=<MmBackward>)
# tensor([[-52399.8945]], grad_fn=<MmBackward>)
# tensor([[-1067184.1250]], grad_fn=<MmBackward>)
# tensor([[-52429.4805]], grad_fn=<MmBackward>)
# tensor([[-1067320.2500]], grad_fn=<MmBackward>)
# tensor([[-52259.0820]], grad_fn=<MmBackward>)
# tensor([[-1067153.7500]], grad_fn=<MmBackward>)
# tensor([[-52510.0703]], grad_fn=<MmBackward>)
# tensor([[-1067344.]], grad_fn=<MmBackward>)
# tensor([[-52455.9805]], grad_fn=<MmBackward>)
# tensor([[-1067529.]], grad_fn=<MmBackward>)
# tensor([[-52391.9648]], grad_fn=<MmBackward>)
# tensor([[-1067350.1250]], grad_fn=<MmBackward>)
# tensor([[-52822.6367]], grad_fn=<MmBackward>)
# tensor([[-1067186.]], grad_fn=<MmBackward>)
# tensor([[-52288.7109]], grad_fn=<MmBackward>)
# tensor([[-1067550.8750]], grad_fn=<MmBackward>)
# tensor([[-52676.5273]], grad_fn=<MmBackward>)
# tensor([[-1067323.2500]], grad_fn=<MmBackward>)
# tensor([[-52453.2578]], grad_fn=<MmBackward>)
# tensor([[-1066833.3750]], grad_fn=<MmBackward>)
# tensor([[-52765.9062]], grad_fn=<MmBackward>)
# tensor([[-1067319.5000]], grad_fn=<MmBackward>)
# tensor([[-52509.0156]], grad_fn=<MmBackward>)
# tensor([[-1067553.6250]], grad_fn=<MmBackward>)
# tensor([[-52415.6719]], grad_fn=<MmBackward>)
# tensor([[-203875.4375]], grad_fn=<MmBackward>)
# tensor([[861792.5000]], grad_fn=<MmBackward>)
# tensor([[-204017.6719]], grad_fn=<MmBackward>)
# tensor([[861278.]], grad_fn=<MmBackward>)
# tensor([[-204070.2656]], grad_fn=<MmBackward>)
# tensor([[861599.3125]], grad_fn=<MmBackward>)
# tensor([[-204444.6406]], grad_fn=<MmBackward>)
# tensor([[861358.3750]], grad_fn=<MmBackward>)
# tensor([[-203921.5156]], grad_fn=<MmBackward>)
# tensor([[861379.6250]], grad_fn=<MmBackward>)
# tensor([[-203916.7656]], grad_fn=<MmBackward>)
# tensor([[861015.5625]], grad_fn=<MmBackward>)
# tensor([[-204223.5625]], grad_fn=<MmBackward>)
# tensor([[861648.5625]], grad_fn=<MmBackward>)
# tensor([[-204336.9531]], grad_fn=<MmBackward>)
# tensor([[861279.2500]], grad_fn=<MmBackward>)
# tensor([[-204212.5625]], grad_fn=<MmBackward>)
# tensor([[861319.7500]], grad_fn=<MmBackward>)
# tensor([[-204185.3750]], grad_fn=<MmBackward>)
# tensor([[861564.2500]], grad_fn=<MmBackward>)
# tensor([[-204054.2656]], grad_fn=<MmBackward>)
# tensor([[861545.1875]], grad_fn=<MmBackward>)
# tensor([[-204235.2344]], grad_fn=<MmBackward>)
# tensor([[861658.4375]], grad_fn=<MmBackward>)
# tensor([[-204420.6719]], grad_fn=<MmBackward>)
# tensor([[861488.9375]], grad_fn=<MmBackward>)
# tensor([[-204317.7500]], grad_fn=<MmBackward>)
# tensor([[861658.0625]], grad_fn=<MmBackward>)
# tensor([[-204533.5781]], grad_fn=<MmBackward>)
# tensor([[861347.1250]], grad_fn=<MmBackward>)
# tensor([[-204579.3750]], grad_fn=<MmBackward>)
# tensor([[861210.5000]], grad_fn=<MmBackward>)
# tensor([[-204220.3750]], grad_fn=<MmBackward>)
# tensor([[861736.6875]], grad_fn=<MmBackward>)
# tensor([[-204088.6719]], grad_fn=<MmBackward>)
# tensor([[861387.8125]], grad_fn=<MmBackward>)
# tensor([[-204301.7500]], grad_fn=<MmBackward>)
# tensor([[861589.6250]], grad_fn=<MmBackward>)
# tensor([[-203944.4844]], grad_fn=<MmBackward>)
# tensor([[861458.9375]], grad_fn=<MmBackward>)
# tensor([[-204300.6094]], grad_fn=<MmBackward>)
# tensor([[861580.4375]], grad_fn=<MmBackward>)
# tensor([[-204005.7500]], grad_fn=<MmBackward>)
# tensor([[861651.7500]], grad_fn=<MmBackward>)
# tensor([[-203653.2031]], grad_fn=<MmBackward>)
# tensor([[861235.8125]], grad_fn=<MmBackward>)
# tensor([[-204121.0938]], grad_fn=<MmBackward>)
# tensor([[861256.5625]], grad_fn=<MmBackward>)
# tensor([[-204738.2344]], grad_fn=<MmBackward>)
# tensor([[861597.3750]], grad_fn=<MmBackward>)
# tensor([[-204181.2031]], grad_fn=<MmBackward>)
# tensor([[860864.]], grad_fn=<MmBackward>)
# tensor([[-204314.8906]], grad_fn=<MmBackward>)
# tensor([[861219.2500]], grad_fn=<MmBackward>)
# tensor([[-204544.0469]], grad_fn=<MmBackward>)
# tensor([[861888.2500]], grad_fn=<MmBackward>)
# tensor([[-204394.4688]], grad_fn=<MmBackward>)
# tensor([[861482.1250]], grad_fn=<MmBackward>)
# tensor([[-204058.6562]], grad_fn=<MmBackward>)
# tensor([[861508.2500]], grad_fn=<MmBackward>)
# tensor([[-204544.]], grad_fn=<MmBackward>)
# tensor([[861699.4375]], grad_fn=<MmBackward>)
# tensor([[-204174.6406]], grad_fn=<MmBackward>)
# tensor([[861520.3125]], grad_fn=<MmBackward>)
# tensor([[-204214.7969]], grad_fn=<MmBackward>)
# tensor([[861481.5000]], grad_fn=<MmBackward>)
# tensor([[-204356.7188]], grad_fn=<MmBackward>)
# tensor([[861672.7500]], grad_fn=<MmBackward>)
# tensor([[-204156.5938]], grad_fn=<MmBackward>)
# tensor([[861437.6250]], grad_fn=<MmBackward>)
# tensor([[-204345.0156]], grad_fn=<MmBackward>)
# tensor([[861421.]], grad_fn=<MmBackward>)
# tensor([[-204549.4844]], grad_fn=<MmBackward>)
# tensor([[861501.5625]], grad_fn=<MmBackward>)
# tensor([[-204309.8125]], grad_fn=<MmBackward>)
# tensor([[861132.8750]], grad_fn=<MmBackward>)
# tensor([[-204176.5938]], grad_fn=<MmBackward>)
# tensor([[861641.6875]], grad_fn=<MmBackward>)
# tensor([[-204570.5156]], grad_fn=<MmBackward>)
# tensor([[861275.2500]], grad_fn=<MmBackward>)
# tensor([[-204348.2031]], grad_fn=<MmBackward>)
# tensor([[861462.5625]], grad_fn=<MmBackward>)
# tensor([[-203930.5000]], grad_fn=<MmBackward>)
# tensor([[861212.6250]], grad_fn=<MmBackward>)
# tensor([[-204334.9062]], grad_fn=<MmBackward>)
# tensor([[861474.8750]], grad_fn=<MmBackward>)
# tensor([[-204493.8906]], grad_fn=<MmBackward>)
# tensor([[861432.5000]], grad_fn=<MmBackward>)
# tensor([[-1066622.2500]], grad_fn=<MmBackward>)
# tensor([[-51829.2422]], grad_fn=<MmBackward>)
# tensor([[-1066741.7500]], grad_fn=<MmBackward>)
# tensor([[-52387.3867]], grad_fn=<MmBackward>)
# tensor([[-1066871.8750]], grad_fn=<MmBackward>)
# tensor([[-52043.8086]], grad_fn=<MmBackward>)
# tensor([[-1067214.6250]], grad_fn=<MmBackward>)
# tensor([[-52290.3398]], grad_fn=<MmBackward>)
# tensor([[-1066620.5000]], grad_fn=<MmBackward>)
# tensor([[-52248.3086]], grad_fn=<MmBackward>)
# tensor([[-1066627.7500]], grad_fn=<MmBackward>)
# tensor([[-52729.6875]], grad_fn=<MmBackward>)
# tensor([[-1067021.1250]], grad_fn=<MmBackward>)
# tensor([[-52010.6992]], grad_fn=<MmBackward>)
# tensor([[-1067126.]], grad_fn=<MmBackward>)
# tensor([[-52402.6797]], grad_fn=<MmBackward>)
# tensor([[-1066951.8750]], grad_fn=<MmBackward>)
# tensor([[-52370.7383]], grad_fn=<MmBackward>)
# tensor([[-1066895.7500]], grad_fn=<MmBackward>)
# tensor([[-52109.4922]], grad_fn=<MmBackward>)
# tensor([[-1066810.1250]], grad_fn=<MmBackward>)
# tensor([[-52084.4219]], grad_fn=<MmBackward>)
# tensor([[-1067043.6250]], grad_fn=<MmBackward>)
# tensor([[-51970.0195]], grad_fn=<MmBackward>)
# tensor([[-1067162.]], grad_fn=<MmBackward>)
# tensor([[-52144.1094]], grad_fn=<MmBackward>)
# tensor([[-1067084.1250]], grad_fn=<MmBackward>)
# tensor([[-51984.0703]], grad_fn=<MmBackward>)
# tensor([[-1067293.]], grad_fn=<MmBackward>)
# tensor([[-52330.0703]], grad_fn=<MmBackward>)
# tensor([[-1067382.8750]], grad_fn=<MmBackward>)
# tensor([[-52471.5312]], grad_fn=<MmBackward>)
# tensor([[-1067002.2500]], grad_fn=<MmBackward>)
# tensor([[-51904.7773]], grad_fn=<MmBackward>)
# tensor([[-1066891.6250]], grad_fn=<MmBackward>)
# tensor([[-52250.3047]], grad_fn=<MmBackward>)
# tensor([[-1067070.6250]], grad_fn=<MmBackward>)
# tensor([[-52037.6367]], grad_fn=<MmBackward>)
# tensor([[-1066677.]], grad_fn=<MmBackward>)
# tensor([[-52133.8047]], grad_fn=<MmBackward>)
# tensor([[-1066998.6250]], grad_fn=<MmBackward>)
# tensor([[-52047.5508]], grad_fn=<MmBackward>)
# tensor([[-1066757.1250]], grad_fn=<MmBackward>)
# tensor([[-51958.9688]], grad_fn=<MmBackward>)
# tensor([[-1066379.1250]], grad_fn=<MmBackward>)
# tensor([[-52403.5547]], grad_fn=<MmBackward>)
# tensor([[-1066864.]], grad_fn=<MmBackward>)
# tensor([[-52440.2852]], grad_fn=<MmBackward>)
# tensor([[-1067506.5000]], grad_fn=<MmBackward>)
# tensor([[-52001.6484]], grad_fn=<MmBackward>)
# tensor([[-1066932.5000]], grad_fn=<MmBackward>)
# tensor([[-52829.8945]], grad_fn=<MmBackward>)
# tensor([[-1066984.5000]], grad_fn=<MmBackward>)
# tensor([[-52445.5039]], grad_fn=<MmBackward>)
# tensor([[-1067339.]], grad_fn=<MmBackward>)
# tensor([[-51757.0977]], grad_fn=<MmBackward>)
# tensor([[-1067151.1250]], grad_fn=<MmBackward>)
# tensor([[-52159.8164]], grad_fn=<MmBackward>)
# tensor([[-1066830.]], grad_fn=<MmBackward>)
# tensor([[-52123.1836]], grad_fn=<MmBackward>)
# tensor([[-1067276.1250]], grad_fn=<MmBackward>)
# tensor([[-51942.0664]], grad_fn=<MmBackward>)
# tensor([[-1066917.1250]], grad_fn=<MmBackward>)
# tensor([[-52127.3633]], grad_fn=<MmBackward>)
# tensor([[-1066971.1250]], grad_fn=<MmBackward>)
# tensor([[-52156.3594]], grad_fn=<MmBackward>)
# tensor([[-1067107.7500]], grad_fn=<MmBackward>)
# tensor([[-51983.8633]], grad_fn=<MmBackward>)
# tensor([[-1066941.5000]], grad_fn=<MmBackward>)
# tensor([[-52237.1953]], grad_fn=<MmBackward>)
# tensor([[-1067133.7500]], grad_fn=<MmBackward>)
# tensor([[-52180.0742]], grad_fn=<MmBackward>)
# tensor([[-1067316.7500]], grad_fn=<MmBackward>)
# tensor([[-52116.6875]], grad_fn=<MmBackward>)
# tensor([[-1067136.2500]], grad_fn=<MmBackward>)
# tensor([[-52549.7383]], grad_fn=<MmBackward>)
# tensor([[-1066975.]], grad_fn=<MmBackward>)
# tensor([[-52014.2578]], grad_fn=<MmBackward>)
# tensor([[-1067339.2500]], grad_fn=<MmBackward>)
# tensor([[-52402.2500]], grad_fn=<MmBackward>)
# tensor([[-1067111.1250]], grad_fn=<MmBackward>)
# tensor([[-52176.9141]], grad_fn=<MmBackward>)
# tensor([[-1066621.6250]], grad_fn=<MmBackward>)
# tensor([[-52492.0859]], grad_fn=<MmBackward>)
# tensor([[-1067109.]], grad_fn=<MmBackward>)
# tensor([[-52235.0391]], grad_fn=<MmBackward>)
# tensor([[-1067339.7500]], grad_fn=<MmBackward>)
# tensor([[-52140.6836]], grad_fn=<MmBackward>)
# tensor([[-204073.1094]], grad_fn=<MmBackward>)
# tensor([[861542.6250]], grad_fn=<MmBackward>)
# tensor([[-204216.4375]], grad_fn=<MmBackward>)
# tensor([[861027.7500]], grad_fn=<MmBackward>)
# tensor([[-204267.6875]], grad_fn=<MmBackward>)
# tensor([[861350.0625]], grad_fn=<MmBackward>)
# tensor([[-204642.3438]], grad_fn=<MmBackward>)
# tensor([[861108.3750]], grad_fn=<MmBackward>)
# tensor([[-204118.4688]], grad_fn=<MmBackward>)
# tensor([[861130.6250]], grad_fn=<MmBackward>)
# tensor([[-204115.2969]], grad_fn=<MmBackward>)
# tensor([[860765.8125]], grad_fn=<MmBackward>)
# tensor([[-204421.0625]], grad_fn=<MmBackward>)
# tensor([[861398.2500]], grad_fn=<MmBackward>)
# tensor([[-204535.2969]], grad_fn=<MmBackward>)
# tensor([[861029.8750]], grad_fn=<MmBackward>)
# tensor([[-204408.6094]], grad_fn=<MmBackward>)
# tensor([[861069.8750]], grad_fn=<MmBackward>)
# tensor([[-204382.2188]], grad_fn=<MmBackward>)
# tensor([[861315.5625]], grad_fn=<MmBackward>)
# tensor([[-204253.2344]], grad_fn=<MmBackward>)
# tensor([[861295.3125]], grad_fn=<MmBackward>)
# tensor([[-204432.5000]], grad_fn=<MmBackward>)
# tensor([[861408.4375]], grad_fn=<MmBackward>)
# tensor([[-204618.8438]], grad_fn=<MmBackward>)
# tensor([[861237.8750]], grad_fn=<MmBackward>)
# tensor([[-204516.2969]], grad_fn=<MmBackward>)
# tensor([[861408.9375]], grad_fn=<MmBackward>)
# tensor([[-204730.9688]], grad_fn=<MmBackward>)
# tensor([[861096.5000]], grad_fn=<MmBackward>)
# tensor([[-204776.0469]], grad_fn=<MmBackward>)
# tensor([[860960.8125]], grad_fn=<MmBackward>)
# tensor([[-204416.9375]], grad_fn=<MmBackward>)
# tensor([[861487.1250]], grad_fn=<MmBackward>)
# tensor([[-204286.4375]], grad_fn=<MmBackward>)
# tensor([[861136.3125]], grad_fn=<MmBackward>)
# tensor([[-204499.2500]], grad_fn=<MmBackward>)
# tensor([[861339.2500]], grad_fn=<MmBackward>)
# tensor([[-204143.0781]], grad_fn=<MmBackward>)
# tensor([[861209.8750]], grad_fn=<MmBackward>)
# tensor([[-204497.1094]], grad_fn=<MmBackward>)
# tensor([[861328.8750]], grad_fn=<MmBackward>)
# tensor([[-204202.9375]], grad_fn=<MmBackward>)
# tensor([[861401.6875]], grad_fn=<MmBackward>)
# tensor([[-203850.6094]], grad_fn=<MmBackward>)
# tensor([[860985.5000]], grad_fn=<MmBackward>)
# tensor([[-204317.1406]], grad_fn=<MmBackward>)
# tensor([[861006.7500]], grad_fn=<MmBackward>)
# tensor([[-204936.5312]], grad_fn=<MmBackward>)
# tensor([[861347.4375]], grad_fn=<MmBackward>)
# tensor([[-204376.9688]], grad_fn=<MmBackward>)
# tensor([[860614.1250]], grad_fn=<MmBackward>)
# tensor([[-204511.7656]], grad_fn=<MmBackward>)
# tensor([[860970.]], grad_fn=<MmBackward>)
# tensor([[-204741.1562]], grad_fn=<MmBackward>)
# tensor([[861638.8750]], grad_fn=<MmBackward>)
# tensor([[-204591.8438]], grad_fn=<MmBackward>)
# tensor([[861231.9375]], grad_fn=<MmBackward>)
# tensor([[-204255.1875]], grad_fn=<MmBackward>)
# tensor([[861258.0625]], grad_fn=<MmBackward>)
# tensor([[-204741.8281]], grad_fn=<MmBackward>)
# tensor([[861449.9375]], grad_fn=<MmBackward>)
# tensor([[-204372.4844]], grad_fn=<MmBackward>)
# tensor([[861270.3125]], grad_fn=<MmBackward>)
# tensor([[-204412.1094]], grad_fn=<MmBackward>)
# tensor([[861231.3750]], grad_fn=<MmBackward>)
# tensor([[-204554.3594]], grad_fn=<MmBackward>)
# tensor([[861422.6875]], grad_fn=<MmBackward>)
# tensor([[-204354.7969]], grad_fn=<MmBackward>)
# tensor([[861188.6875]], grad_fn=<MmBackward>)
# tensor([[-204543.6406]], grad_fn=<MmBackward>)
# tensor([[861171.0625]], grad_fn=<MmBackward>)
# tensor([[-204746.3594]], grad_fn=<MmBackward>)
# tensor([[861250.5000]], grad_fn=<MmBackward>)
# tensor([[-204506.9688]], grad_fn=<MmBackward>)
# tensor([[860882.4375]], grad_fn=<MmBackward>)
# tensor([[-204373.1875]], grad_fn=<MmBackward>)
# tensor([[861392.0625]], grad_fn=<MmBackward>)
# tensor([[-204766.7812]], grad_fn=<MmBackward>)
# tensor([[861024.8125]], grad_fn=<MmBackward>)
# tensor([[-204544.7188]], grad_fn=<MmBackward>)
# tensor([[861212.8125]], grad_fn=<MmBackward>)
# tensor([[-204128.7656]], grad_fn=<MmBackward>)
# tensor([[860962.3125]], grad_fn=<MmBackward>)
# tensor([[-204532.1719]], grad_fn=<MmBackward>)
# tensor([[861224.8125]], grad_fn=<MmBackward>)
# tensor([[-204691.1875]], grad_fn=<MmBackward>)
# tensor([[861182.0625]], grad_fn=<MmBackward>)
# tensor([[-1066689.6250]], grad_fn=<MmBackward>)
# tensor([[-51987.4141]], grad_fn=<MmBackward>)
# tensor([[-1066810.2500]], grad_fn=<MmBackward>)
# tensor([[-52546.2969]], grad_fn=<MmBackward>)
# tensor([[-1066939.6250]], grad_fn=<MmBackward>)
# tensor([[-52202.5703]], grad_fn=<MmBackward>)
# tensor([[-1067286.6250]], grad_fn=<MmBackward>)
# tensor([[-52448.1016]], grad_fn=<MmBackward>)
# tensor([[-1066689.3750]], grad_fn=<MmBackward>)
# tensor([[-52405.3320]], grad_fn=<MmBackward>)
# tensor([[-1066695.6250]], grad_fn=<MmBackward>)
# tensor([[-52887.8125]], grad_fn=<MmBackward>)
# tensor([[-1067088.1250]], grad_fn=<MmBackward>)
# tensor([[-52168.6250]], grad_fn=<MmBackward>)
# tensor([[-1067196.1250]], grad_fn=<MmBackward>)
# tensor([[-52559.4297]], grad_fn=<MmBackward>)
# tensor([[-1067020.5000]], grad_fn=<MmBackward>)
# tensor([[-52529.2695]], grad_fn=<MmBackward>)
# tensor([[-1066964.6250]], grad_fn=<MmBackward>)
# tensor([[-52267.8516]], grad_fn=<MmBackward>)
# tensor([[-1066879.]], grad_fn=<MmBackward>)
# tensor([[-52242.9258]], grad_fn=<MmBackward>)
# tensor([[-1067112.]], grad_fn=<MmBackward>)
# tensor([[-52127.4844]], grad_fn=<MmBackward>)
# tensor([[-1067229.7500]], grad_fn=<MmBackward>)
# tensor([[-52304.1875]], grad_fn=<MmBackward>)
# tensor([[-1067152.7500]], grad_fn=<MmBackward>)
# tensor([[-52142.2656]], grad_fn=<MmBackward>)
# tensor([[-1067362.5000]], grad_fn=<MmBackward>)
# tensor([[-52488.8711]], grad_fn=<MmBackward>)
# tensor([[-1067451.1250]], grad_fn=<MmBackward>)
# tensor([[-52630.4102]], grad_fn=<MmBackward>)
# tensor([[-1067068.3750]], grad_fn=<MmBackward>)
# tensor([[-52062.8750]], grad_fn=<MmBackward>)
# tensor([[-1066961.]], grad_fn=<MmBackward>)
# tensor([[-52408.2891]], grad_fn=<MmBackward>)
# tensor([[-1067140.7500]], grad_fn=<MmBackward>)
# tensor([[-52195.2188]], grad_fn=<MmBackward>)
# tensor([[-1066743.8750]], grad_fn=<MmBackward>)
# tensor([[-52293.6289]], grad_fn=<MmBackward>)
# tensor([[-1067068.1250]], grad_fn=<MmBackward>)
# tensor([[-52205.5391]], grad_fn=<MmBackward>)
# tensor([[-1066826.]], grad_fn=<MmBackward>)
# tensor([[-52116.5078]], grad_fn=<MmBackward>)
# tensor([[-1066449.]], grad_fn=<MmBackward>)
# tensor([[-52561.9180]], grad_fn=<MmBackward>)
# tensor([[-1066931.7500]], grad_fn=<MmBackward>)
# tensor([[-52598.4688]], grad_fn=<MmBackward>)
# tensor([[-1067574.5000]], grad_fn=<MmBackward>)
# tensor([[-52161.0898]], grad_fn=<MmBackward>)
# tensor([[-1067000.3750]], grad_fn=<MmBackward>)
# tensor([[-52988.9727]], grad_fn=<MmBackward>)
# tensor([[-1067054.7500]], grad_fn=<MmBackward>)
# tensor([[-52603.1641]], grad_fn=<MmBackward>)
# tensor([[-1067407.8750]], grad_fn=<MmBackward>)
# tensor([[-51914.8867]], grad_fn=<MmBackward>)
# tensor([[-1067220.1250]], grad_fn=<MmBackward>)
# tensor([[-52316.3516]], grad_fn=<MmBackward>)
# tensor([[-1066897.6250]], grad_fn=<MmBackward>)
# tensor([[-52280.8398]], grad_fn=<MmBackward>)
# tensor([[-1067345.2500]], grad_fn=<MmBackward>)
# tensor([[-52100.5391]], grad_fn=<MmBackward>)
# tensor([[-1066986.2500]], grad_fn=<MmBackward>)
# tensor([[-52283.7305]], grad_fn=<MmBackward>)
# tensor([[-1067041.3750]], grad_fn=<MmBackward>)
# tensor([[-52314.5117]], grad_fn=<MmBackward>)
# tensor([[-1067176.2500]], grad_fn=<MmBackward>)
# tensor([[-52142.0938]], grad_fn=<MmBackward>)
# tensor([[-1067010.1250]], grad_fn=<MmBackward>)
# tensor([[-52394.2578]], grad_fn=<MmBackward>)
# tensor([[-1067199.6250]], grad_fn=<MmBackward>)
# tensor([[-52337.3086]], grad_fn=<MmBackward>)
# tensor([[-1067385.7500]], grad_fn=<MmBackward>)
# tensor([[-52275.1914]], grad_fn=<MmBackward>)
# tensor([[-1067206.7500]], grad_fn=<MmBackward>)
# tensor([[-52706.3984]], grad_fn=<MmBackward>)
# tensor([[-1067042.1250]], grad_fn=<MmBackward>)
# tensor([[-52172.1523]], grad_fn=<MmBackward>)
# tensor([[-1067407.3750]], grad_fn=<MmBackward>)
# tensor([[-52561.6719]], grad_fn=<MmBackward>)
# tensor([[-1067178.5000]], grad_fn=<MmBackward>)
# tensor([[-52334.0195]], grad_fn=<MmBackward>)
# tensor([[-1066691.8750]], grad_fn=<MmBackward>)
# tensor([[-52649.0820]], grad_fn=<MmBackward>)
# tensor([[-1067176.1250]], grad_fn=<MmBackward>)
# tensor([[-52393.5117]], grad_fn=<MmBackward>)
# tensor([[-1067410.5000]], grad_fn=<MmBackward>)
# tensor([[-52297.4609]], grad_fn=<MmBackward>)
# tensor([[-203591.0469]], grad_fn=<MmBackward>)
# tensor([[862080.1250]], grad_fn=<MmBackward>)
# tensor([[-203735.2656]], grad_fn=<MmBackward>)
# tensor([[861564.6875]], grad_fn=<MmBackward>)
# tensor([[-203785.2500]], grad_fn=<MmBackward>)
# tensor([[861886.8125]], grad_fn=<MmBackward>)
# tensor([[-204160.2188]], grad_fn=<MmBackward>)
# tensor([[861645.2500]], grad_fn=<MmBackward>)
# tensor([[-203636.1094]], grad_fn=<MmBackward>)
# tensor([[861668.]], grad_fn=<MmBackward>)
# tensor([[-203632.5000]], grad_fn=<MmBackward>)
# tensor([[861303.2500]], grad_fn=<MmBackward>)
# tensor([[-203939.7656]], grad_fn=<MmBackward>)
# tensor([[861935.8125]], grad_fn=<MmBackward>)
# tensor([[-204051.9844]], grad_fn=<MmBackward>)
# tensor([[861566.5000]], grad_fn=<MmBackward>)
# tensor([[-203926.9375]], grad_fn=<MmBackward>)
# tensor([[861606.4375]], grad_fn=<MmBackward>)
# tensor([[-203900.3750]], grad_fn=<MmBackward>)
# tensor([[861853.1875]], grad_fn=<MmBackward>)
# tensor([[-203770.2656]], grad_fn=<MmBackward>)
# tensor([[861831.9375]], grad_fn=<MmBackward>)
# tensor([[-203950.0156]], grad_fn=<MmBackward>)
# tensor([[861946.5000]], grad_fn=<MmBackward>)
# tensor([[-204134.7500]], grad_fn=<MmBackward>)
# tensor([[861776.0625]], grad_fn=<MmBackward>)
# tensor([[-204033.0469]], grad_fn=<MmBackward>)
# tensor([[861945.8750]], grad_fn=<MmBackward>)
# tensor([[-204248.4688]], grad_fn=<MmBackward>)
# tensor([[861634.]], grad_fn=<MmBackward>)
# tensor([[-204293.9062]], grad_fn=<MmBackward>)
# tensor([[861498.3125]], grad_fn=<MmBackward>)
# tensor([[-203935.0469]], grad_fn=<MmBackward>)
# tensor([[862024.3125]], grad_fn=<MmBackward>)
# tensor([[-203804.]], grad_fn=<MmBackward>)
# tensor([[861673.6875]], grad_fn=<MmBackward>)
# tensor([[-204017.5469]], grad_fn=<MmBackward>)
# tensor([[861876.6875]], grad_fn=<MmBackward>)
# tensor([[-203660.7500]], grad_fn=<MmBackward>)
# tensor([[861744.8750]], grad_fn=<MmBackward>)
# tensor([[-204014.2500]], grad_fn=<MmBackward>)
# tensor([[861866.9375]], grad_fn=<MmBackward>)
# tensor([[-203720.4062]], grad_fn=<MmBackward>)
# tensor([[861938.5000]], grad_fn=<MmBackward>)
# tensor([[-203367.9062]], grad_fn=<MmBackward>)
# tensor([[861522.5000]], grad_fn=<MmBackward>)
# tensor([[-203834.8125]], grad_fn=<MmBackward>)
# tensor([[861545.8125]], grad_fn=<MmBackward>)
# tensor([[-204452.7031]], grad_fn=<MmBackward>)
# tensor([[861885.8125]], grad_fn=<MmBackward>)
# tensor([[-203895.4531]], grad_fn=<MmBackward>)
# tensor([[861151.3750]], grad_fn=<MmBackward>)
# tensor([[-204029.1719]], grad_fn=<MmBackward>)
# tensor([[861506.6250]], grad_fn=<MmBackward>)
# tensor([[-204258.0156]], grad_fn=<MmBackward>)
# tensor([[862176.8125]], grad_fn=<MmBackward>)
# tensor([[-204109.4688]], grad_fn=<MmBackward>)
# tensor([[861769.4375]], grad_fn=<MmBackward>)
# tensor([[-203773.2500]], grad_fn=<MmBackward>)
# tensor([[861796.8750]], grad_fn=<MmBackward>)
# tensor([[-204259.0312]], grad_fn=<MmBackward>)
# tensor([[861987.1250]], grad_fn=<MmBackward>)
# tensor([[-203889.5469]], grad_fn=<MmBackward>)
# tensor([[861807.5000]], grad_fn=<MmBackward>)
# tensor([[-203930.4375]], grad_fn=<MmBackward>)
# tensor([[861768.8750]], grad_fn=<MmBackward>)
# tensor([[-204071.4219]], grad_fn=<MmBackward>)
# tensor([[861961.2500]], grad_fn=<MmBackward>)
# tensor([[-203871.3281]], grad_fn=<MmBackward>)
# tensor([[861725.3125]], grad_fn=<MmBackward>)
# tensor([[-204059.9375]], grad_fn=<MmBackward>)
# tensor([[861708.]], grad_fn=<MmBackward>)
# tensor([[-204263.7500]], grad_fn=<MmBackward>)
# tensor([[861788.1875]], grad_fn=<MmBackward>)
# tensor([[-204025.2188]], grad_fn=<MmBackward>)
# tensor([[861419.8750]], grad_fn=<MmBackward>)
# tensor([[-203892.2812]], grad_fn=<MmBackward>)
# tensor([[861928.3125]], grad_fn=<MmBackward>)
# tensor([[-204284.0781]], grad_fn=<MmBackward>)
# tensor([[861562.8125]], grad_fn=<MmBackward>)
# tensor([[-204063.1719]], grad_fn=<MmBackward>)
# tensor([[861751.2500]], grad_fn=<MmBackward>)
# tensor([[-203646.5312]], grad_fn=<MmBackward>)
# tensor([[861500.5625]], grad_fn=<MmBackward>)
# tensor([[-204049.3906]], grad_fn=<MmBackward>)
# tensor([[861763.1250]], grad_fn=<MmBackward>)
# tensor([[-204208.7500]], grad_fn=<MmBackward>)
# tensor([[861719.0625]], grad_fn=<MmBackward>)
# tensor([[-1066895.8750]], grad_fn=<MmBackward>)
# tensor([[-52186.8789]], grad_fn=<MmBackward>)
# tensor([[-1067013.5000]], grad_fn=<MmBackward>)
# tensor([[-52744.7695]], grad_fn=<MmBackward>)
# tensor([[-1067143.7500]], grad_fn=<MmBackward>)
# tensor([[-52401.3672]], grad_fn=<MmBackward>)
# tensor([[-1067490.3750]], grad_fn=<MmBackward>)
# tensor([[-52648.4102]], grad_fn=<MmBackward>)
# tensor([[-1066893.8750]], grad_fn=<MmBackward>)
# tensor([[-52606.1211]], grad_fn=<MmBackward>)
# tensor([[-1066900.5000]], grad_fn=<MmBackward>)
# tensor([[-53086.4453]], grad_fn=<MmBackward>)
# tensor([[-1067292.8750]], grad_fn=<MmBackward>)
# tensor([[-52368.8203]], grad_fn=<MmBackward>)
# tensor([[-1067401.]], grad_fn=<MmBackward>)
# tensor([[-52758.6875]], grad_fn=<MmBackward>)
# tensor([[-1067226.3750]], grad_fn=<MmBackward>)
# tensor([[-52727.8125]], grad_fn=<MmBackward>)
# tensor([[-1067170.2500]], grad_fn=<MmBackward>)
# tensor([[-52467.7031]], grad_fn=<MmBackward>)
# tensor([[-1067082.]], grad_fn=<MmBackward>)
# tensor([[-52442.7773]], grad_fn=<MmBackward>)
# tensor([[-1067318.1250]], grad_fn=<MmBackward>)
# tensor([[-52326.2109]], grad_fn=<MmBackward>)
# tensor([[-1067434.8750]], grad_fn=<MmBackward>)
# tensor([[-52502.7070]], grad_fn=<MmBackward>)
# tensor([[-1067356.5000]], grad_fn=<MmBackward>)
# tensor([[-52341.5273]], grad_fn=<MmBackward>)
# tensor([[-1067567.3750]], grad_fn=<MmBackward>)
# tensor([[-52685.9219]], grad_fn=<MmBackward>)
# tensor([[-1067656.5000]], grad_fn=<MmBackward>)
# tensor([[-52827.7617]], grad_fn=<MmBackward>)
# tensor([[-1067274.3750]], grad_fn=<MmBackward>)
# tensor([[-52261.3359]], grad_fn=<MmBackward>)
# tensor([[-1067167.3750]], grad_fn=<MmBackward>)
# tensor([[-52608.0664]], grad_fn=<MmBackward>)
# tensor([[-1067346.6250]], grad_fn=<MmBackward>)
# tensor([[-52395.6484]], grad_fn=<MmBackward>)
# tensor([[-1066948.1250]], grad_fn=<MmBackward>)
# tensor([[-52491.1562]], grad_fn=<MmBackward>)
# tensor([[-1067272.2500]], grad_fn=<MmBackward>)
# tensor([[-52404.1406]], grad_fn=<MmBackward>)
# tensor([[-1067031.]], grad_fn=<MmBackward>)
# tensor([[-52316.1445]], grad_fn=<MmBackward>)
# tensor([[-1066653.2500]], grad_fn=<MmBackward>)
# tensor([[-52760.0820]], grad_fn=<MmBackward>)
# tensor([[-1067136.2500]], grad_fn=<MmBackward>)
# tensor([[-52798.7461]], grad_fn=<MmBackward>)
# tensor([[-1067779.3750]], grad_fn=<MmBackward>)
# tensor([[-52358.5000]], grad_fn=<MmBackward>)
# tensor([[-1067205.3750]], grad_fn=<MmBackward>)
# tensor([[-53187.1680]], grad_fn=<MmBackward>)
# tensor([[-1067258.8750]], grad_fn=<MmBackward>)
# tensor([[-52803.6836]], grad_fn=<MmBackward>)
# tensor([[-1067613.3750]], grad_fn=<MmBackward>)
# tensor([[-52114.6094]], grad_fn=<MmBackward>)
# tensor([[-1067426.1250]], grad_fn=<MmBackward>)
# tensor([[-52517.9492]], grad_fn=<MmBackward>)
# tensor([[-1067102.2500]], grad_fn=<MmBackward>)
# tensor([[-52480.8242]], grad_fn=<MmBackward>)
# tensor([[-1067550.7500]], grad_fn=<MmBackward>)
# tensor([[-52298.5820]], grad_fn=<MmBackward>)
# tensor([[-1067190.3750]], grad_fn=<MmBackward>)
# tensor([[-52484.4414]], grad_fn=<MmBackward>)
# tensor([[-1067245.7500]], grad_fn=<MmBackward>)
# tensor([[-52514.9922]], grad_fn=<MmBackward>)
# tensor([[-1067382.1250]], grad_fn=<MmBackward>)
# tensor([[-52342.2969]], grad_fn=<MmBackward>)
# tensor([[-1067214.5000]], grad_fn=<MmBackward>)
# tensor([[-52593.9414]], grad_fn=<MmBackward>)
# tensor([[-1067406.]], grad_fn=<MmBackward>)
# tensor([[-52539.4688]], grad_fn=<MmBackward>)
# tensor([[-1067590.3750]], grad_fn=<MmBackward>)
# tensor([[-52475.5508]], grad_fn=<MmBackward>)
# tensor([[-1067412.]], grad_fn=<MmBackward>)
# tensor([[-52906.6328]], grad_fn=<MmBackward>)
# tensor([[-1067249.]], grad_fn=<MmBackward>)
# tensor([[-52371.8047]], grad_fn=<MmBackward>)
# tensor([[-1067613.]], grad_fn=<MmBackward>)
# tensor([[-52759.9727]], grad_fn=<MmBackward>)
# tensor([[-1067382.8750]], grad_fn=<MmBackward>)
# tensor([[-52534.7500]], grad_fn=<MmBackward>)
# tensor([[-1066895.6250]], grad_fn=<MmBackward>)
# tensor([[-52849.2617]], grad_fn=<MmBackward>)
# tensor([[-1067382.3750]], grad_fn=<MmBackward>)
# tensor([[-52591.6719]], grad_fn=<MmBackward>)
# tensor([[-1067613.5000]], grad_fn=<MmBackward>)
# tensor([[-52497.2734]], grad_fn=<MmBackward>)
# tensor([[-203411.9062]], grad_fn=<MmBackward>)
# tensor([[862240.5625]], grad_fn=<MmBackward>)
# tensor([[-203555.1406]], grad_fn=<MmBackward>)
# tensor([[861724.9375]], grad_fn=<MmBackward>)
# tensor([[-203605.3750]], grad_fn=<MmBackward>)
# tensor([[862045.6875]], grad_fn=<MmBackward>)
# tensor([[-203981.0625]], grad_fn=<MmBackward>)
# tensor([[861804.5000]], grad_fn=<MmBackward>)
# tensor([[-203457.5156]], grad_fn=<MmBackward>)
# tensor([[861827.2500]], grad_fn=<MmBackward>)
# tensor([[-203453.7969]], grad_fn=<MmBackward>)
# tensor([[861462.2500]], grad_fn=<MmBackward>)
# tensor([[-203760.6562]], grad_fn=<MmBackward>)
# tensor([[862094.8750]], grad_fn=<MmBackward>)
# tensor([[-203874.1562]], grad_fn=<MmBackward>)
# tensor([[861724.7500]], grad_fn=<MmBackward>)
# tensor([[-203747.6719]], grad_fn=<MmBackward>)
# tensor([[861766.2500]], grad_fn=<MmBackward>)
# tensor([[-203721.4531]], grad_fn=<MmBackward>)
# tensor([[862011.1875]], grad_fn=<MmBackward>)
# tensor([[-203591.6875]], grad_fn=<MmBackward>)
# tensor([[861991.9375]], grad_fn=<MmBackward>)
# tensor([[-203771.5938]], grad_fn=<MmBackward>)
# tensor([[862104.3750]], grad_fn=<MmBackward>)
# tensor([[-203956.9531]], grad_fn=<MmBackward>)
# tensor([[861936.3125]], grad_fn=<MmBackward>)
# tensor([[-203854.1562]], grad_fn=<MmBackward>)
# tensor([[862105.5625]], grad_fn=<MmBackward>)
# tensor([[-204071.1875]], grad_fn=<MmBackward>)
# tensor([[861794.0625]], grad_fn=<MmBackward>)
# tensor([[-204115.7812]], grad_fn=<MmBackward>)
# tensor([[861658.2500]], grad_fn=<MmBackward>)
# tensor([[-203756.9844]], grad_fn=<MmBackward>)
# tensor([[862182.9375]], grad_fn=<MmBackward>)
# tensor([[-203625.8906]], grad_fn=<MmBackward>)
# tensor([[861834.1250]], grad_fn=<MmBackward>)
# tensor([[-203837.4531]], grad_fn=<MmBackward>)
# tensor([[862036.5625]], grad_fn=<MmBackward>)
# tensor([[-203480.3438]], grad_fn=<MmBackward>)
# tensor([[861905.3125]], grad_fn=<MmBackward>)
# tensor([[-203836.4531]], grad_fn=<MmBackward>)
# tensor([[862026.1250]], grad_fn=<MmBackward>)
# tensor([[-203542.7969]], grad_fn=<MmBackward>)
# tensor([[862097.9375]], grad_fn=<MmBackward>)
# tensor([[-203189.5000]], grad_fn=<MmBackward>)
# tensor([[861682.1875]], grad_fn=<MmBackward>)
# tensor([[-203657.5781]], grad_fn=<MmBackward>)
# tensor([[861703.3750]], grad_fn=<MmBackward>)
# tensor([[-204275.7969]], grad_fn=<MmBackward>)
# tensor([[862044.4375]], grad_fn=<MmBackward>)
# tensor([[-203717.7344]], grad_fn=<MmBackward>)
# tensor([[861310.8125]], grad_fn=<MmBackward>)
# tensor([[-203852.9688]], grad_fn=<MmBackward>)
# tensor([[861665.6250]], grad_fn=<MmBackward>)
# tensor([[-204080.6406]], grad_fn=<MmBackward>)
# tensor([[862335.7500]], grad_fn=<MmBackward>)
# tensor([[-203930.6094]], grad_fn=<MmBackward>)
# tensor([[861929.4375]], grad_fn=<MmBackward>)
# tensor([[-203595.4062]], grad_fn=<MmBackward>)
# tensor([[861954.3125]], grad_fn=<MmBackward>)
# tensor([[-204079.9375]], grad_fn=<MmBackward>)
# tensor([[862145.3125]], grad_fn=<MmBackward>)
# tensor([[-203711.8906]], grad_fn=<MmBackward>)
# tensor([[861967.3750]], grad_fn=<MmBackward>)
# tensor([[-203752.2812]], grad_fn=<MmBackward>)
# tensor([[861927.3125]], grad_fn=<MmBackward>)
# tensor([[-203893.7969]], grad_fn=<MmBackward>)
# tensor([[862120.6250]], grad_fn=<MmBackward>)
# tensor([[-203692.5312]], grad_fn=<MmBackward>)
# tensor([[861884.]], grad_fn=<MmBackward>)
# tensor([[-203881.8438]], grad_fn=<MmBackward>)
# tensor([[861866.8750]], grad_fn=<MmBackward>)
# tensor([[-204084.7344]], grad_fn=<MmBackward>)
# tensor([[861948.1250]], grad_fn=<MmBackward>)
# tensor([[-203845.9062]], grad_fn=<MmBackward>)
# tensor([[861578.5000]], grad_fn=<MmBackward>)
# tensor([[-203713.7500]], grad_fn=<MmBackward>)
# tensor([[862089.1250]], grad_fn=<MmBackward>)
# tensor([[-204105.9531]], grad_fn=<MmBackward>)
# tensor([[861722.5000]], grad_fn=<MmBackward>)
# tensor([[-203884.3281]], grad_fn=<MmBackward>)
# tensor([[861909.4375]], grad_fn=<MmBackward>)
# tensor([[-203469.1562]], grad_fn=<MmBackward>)
# tensor([[861660.]], grad_fn=<MmBackward>)
# tensor([[-203870.4375]], grad_fn=<MmBackward>)
# tensor([[861921.7500]], grad_fn=<MmBackward>)
# tensor([[-204031.5156]], grad_fn=<MmBackward>)
# tensor([[861878.5000]], grad_fn=<MmBackward>)
# tensor([[-1066970.5000]], grad_fn=<MmBackward>)
# tensor([[-52251.6484]], grad_fn=<MmBackward>)
# tensor([[-1067087.6250]], grad_fn=<MmBackward>)
# tensor([[-52809.6406]], grad_fn=<MmBackward>)
# tensor([[-1067218.5000]], grad_fn=<MmBackward>)
# tensor([[-52465.7109]], grad_fn=<MmBackward>)
# tensor([[-1067562.8750]], grad_fn=<MmBackward>)
# tensor([[-52712.2188]], grad_fn=<MmBackward>)
# tensor([[-1066967.3750]], grad_fn=<MmBackward>)
# tensor([[-52670.1641]], grad_fn=<MmBackward>)
# tensor([[-1066973.7500]], grad_fn=<MmBackward>)
# tensor([[-53151.8320]], grad_fn=<MmBackward>)
# tensor([[-1067366.1250]], grad_fn=<MmBackward>)
# tensor([[-52432.3594]], grad_fn=<MmBackward>)
# tensor([[-1067474.2500]], grad_fn=<MmBackward>)
# tensor([[-52825.5547]], grad_fn=<MmBackward>)
# tensor([[-1067298.7500]], grad_fn=<MmBackward>)
# tensor([[-52792.8672]], grad_fn=<MmBackward>)
# tensor([[-1067242.]], grad_fn=<MmBackward>)
# tensor([[-52532.1211]], grad_fn=<MmBackward>)
# tensor([[-1067156.]], grad_fn=<MmBackward>)
# tensor([[-52507.0820]], grad_fn=<MmBackward>)
# tensor([[-1067391.5000]], grad_fn=<MmBackward>)
# tensor([[-52391.6602]], grad_fn=<MmBackward>)
# tensor([[-1067507.]], grad_fn=<MmBackward>)
# tensor([[-52567.5977]], grad_fn=<MmBackward>)
# tensor([[-1067430.8750]], grad_fn=<MmBackward>)
# tensor([[-52405.8281]], grad_fn=<MmBackward>)
# tensor([[-1067639.2500]], grad_fn=<MmBackward>)
# tensor([[-52750.9258]], grad_fn=<MmBackward>)
# tensor([[-1067730.5000]], grad_fn=<MmBackward>)
# tensor([[-52893.4297]], grad_fn=<MmBackward>)
# tensor([[-1067347.]], grad_fn=<MmBackward>)
# tensor([[-52326.6875]], grad_fn=<MmBackward>)
# tensor([[-1067239.]], grad_fn=<MmBackward>)
# tensor([[-52672.5078]], grad_fn=<MmBackward>)
# tensor([[-1067417.]], grad_fn=<MmBackward>)
# tensor([[-52459.7812]], grad_fn=<MmBackward>)
# tensor([[-1067021.7500]], grad_fn=<MmBackward>)
# tensor([[-52554.4062]], grad_fn=<MmBackward>)
# tensor([[-1067344.7500]], grad_fn=<MmBackward>)
# tensor([[-52469.9570]], grad_fn=<MmBackward>)
# tensor([[-1067103.7500]], grad_fn=<MmBackward>)
# tensor([[-52380.1836]], grad_fn=<MmBackward>)
# tensor([[-1066725.5000]], grad_fn=<MmBackward>)
# tensor([[-52825.9688]], grad_fn=<MmBackward>)
# tensor([[-1067209.7500]], grad_fn=<MmBackward>)
# tensor([[-52862.2344]], grad_fn=<MmBackward>)
# tensor([[-1067853.3750]], grad_fn=<MmBackward>)
# tensor([[-52424.2188]], grad_fn=<MmBackward>)
# tensor([[-1067279.3750]], grad_fn=<MmBackward>)
# tensor([[-53252.1484]], grad_fn=<MmBackward>)
# tensor([[-1067332.1250]], grad_fn=<MmBackward>)
# tensor([[-52866.6484]], grad_fn=<MmBackward>)
# tensor([[-1067687.5000]], grad_fn=<MmBackward>)
# tensor([[-52177.8086]], grad_fn=<MmBackward>)
# tensor([[-1067497.8750]], grad_fn=<MmBackward>)
# tensor([[-52581.5703]], grad_fn=<MmBackward>)
# tensor([[-1067176.]], grad_fn=<MmBackward>)
# tensor([[-52546.1719]], grad_fn=<MmBackward>)
# tensor([[-1067622.3750]], grad_fn=<MmBackward>)
# tensor([[-52363.7578]], grad_fn=<MmBackward>)
# tensor([[-1067264.2500]], grad_fn=<MmBackward>)
# tensor([[-52548.4883]], grad_fn=<MmBackward>)
# tensor([[-1067318.7500]], grad_fn=<MmBackward>)
# tensor([[-52578.1523]], grad_fn=<MmBackward>)
# tensor([[-1067456.5000]], grad_fn=<MmBackward>)
# tensor([[-52407.2578]], grad_fn=<MmBackward>)
# tensor([[-1067285.3750]], grad_fn=<MmBackward>)
# tensor([[-52658.6641]], grad_fn=<MmBackward>)
# tensor([[-1067478.8750]], grad_fn=<MmBackward>)
# tensor([[-52603.0117]], grad_fn=<MmBackward>)
# tensor([[-1067664.6250]], grad_fn=<MmBackward>)
# tensor([[-52539.0195]], grad_fn=<MmBackward>)
# tensor([[-1067482.7500]], grad_fn=<MmBackward>)
# tensor([[-52970.8672]], grad_fn=<MmBackward>)
# tensor([[-1067321.7500]], grad_fn=<MmBackward>)
# tensor([[-52435.7305]], grad_fn=<MmBackward>)
# tensor([[-1067684.8750]], grad_fn=<MmBackward>)
# tensor([[-52826.0391]], grad_fn=<MmBackward>)
# tensor([[-1067456.6250]], grad_fn=<MmBackward>)
# tensor([[-52599.8281]], grad_fn=<MmBackward>)
# tensor([[-1066968.]], grad_fn=<MmBackward>)
# tensor([[-52915.0469]], grad_fn=<MmBackward>)
# tensor([[-1067455.1250]], grad_fn=<MmBackward>)
# tensor([[-52656.3281]], grad_fn=<MmBackward>)
# tensor([[-1067689.1250]], grad_fn=<MmBackward>)
# tensor([[-52562.9922]], grad_fn=<MmBackward>)
# tensor([[-203568.8125]], grad_fn=<MmBackward>)
# tensor([[862101.5625]], grad_fn=<MmBackward>)
# tensor([[-203712.0312]], grad_fn=<MmBackward>)
# tensor([[861585.9375]], grad_fn=<MmBackward>)
# tensor([[-203762.7969]], grad_fn=<MmBackward>)
# tensor([[861908.0625]], grad_fn=<MmBackward>)
# tensor([[-204138.1094]], grad_fn=<MmBackward>)
# tensor([[861667.2500]], grad_fn=<MmBackward>)
# tensor([[-203614.6562]], grad_fn=<MmBackward>)
# tensor([[861688.8125]], grad_fn=<MmBackward>)
# tensor([[-203610.3125]], grad_fn=<MmBackward>)
# tensor([[861323.9375]], grad_fn=<MmBackward>)
# tensor([[-203917.1719]], grad_fn=<MmBackward>)
# tensor([[861957.6875]], grad_fn=<MmBackward>)
# tensor([[-204030.2812]], grad_fn=<MmBackward>)
# tensor([[861587.0625]], grad_fn=<MmBackward>)
# tensor([[-203904.9531]], grad_fn=<MmBackward>)
# tensor([[861627.9375]], grad_fn=<MmBackward>)
# tensor([[-203877.9062]], grad_fn=<MmBackward>)
# tensor([[861872.8750]], grad_fn=<MmBackward>)
# tensor([[-203748.1250]], grad_fn=<MmBackward>)
# tensor([[861853.4375]], grad_fn=<MmBackward>)
# tensor([[-203927.3438]], grad_fn=<MmBackward>)
# tensor([[861965.6875]], grad_fn=<MmBackward>)
# tensor([[-204113.3281]], grad_fn=<MmBackward>)
# tensor([[861797.5000]], grad_fn=<MmBackward>)
# tensor([[-204010.5938]], grad_fn=<MmBackward>)
# tensor([[861966.6875]], grad_fn=<MmBackward>)
# tensor([[-204226.8125]], grad_fn=<MmBackward>)
# tensor([[861655.1250]], grad_fn=<MmBackward>)
# tensor([[-204271.3281]], grad_fn=<MmBackward>)
# tensor([[861519.6875]], grad_fn=<MmBackward>)
# tensor([[-203912.7500]], grad_fn=<MmBackward>)
# tensor([[862044.5000]], grad_fn=<MmBackward>)
# tensor([[-203782.5469]], grad_fn=<MmBackward>)
# tensor([[861695.8750]], grad_fn=<MmBackward>)
# tensor([[-203993.5938]], grad_fn=<MmBackward>)
# tensor([[861897.4375]], grad_fn=<MmBackward>)
# tensor([[-203637.9688]], grad_fn=<MmBackward>)
# tensor([[861767.1250]], grad_fn=<MmBackward>)
# tensor([[-203991.2188]], grad_fn=<MmBackward>)
# tensor([[861888.1250]], grad_fn=<MmBackward>)
# tensor([[-203698.8750]], grad_fn=<MmBackward>)
# tensor([[861959.4375]], grad_fn=<MmBackward>)
# tensor([[-203345.0625]], grad_fn=<MmBackward>)
# tensor([[861544.]], grad_fn=<MmBackward>)
# tensor([[-203812.4375]], grad_fn=<MmBackward>)
# tensor([[861566.2500]], grad_fn=<MmBackward>)
# tensor([[-204431.2656]], grad_fn=<MmBackward>)
# tensor([[861906.4375]], grad_fn=<MmBackward>)
# tensor([[-203873.1406]], grad_fn=<MmBackward>)
# tensor([[861171.6875]], grad_fn=<MmBackward>)
# tensor([[-204008.2344]], grad_fn=<MmBackward>)
# tensor([[861528.]], grad_fn=<MmBackward>)
# tensor([[-204235.8281]], grad_fn=<MmBackward>)
# tensor([[862196.7500]], grad_fn=<MmBackward>)
# tensor([[-204086.9688]], grad_fn=<MmBackward>)
# tensor([[861789.9375]], grad_fn=<MmBackward>)
# tensor([[-203749.3125]], grad_fn=<MmBackward>)
# tensor([[861816.5625]], grad_fn=<MmBackward>)
# tensor([[-204236.5312]], grad_fn=<MmBackward>)
# tensor([[862008.5625]], grad_fn=<MmBackward>)
# tensor([[-203867.6250]], grad_fn=<MmBackward>)
# tensor([[861828.5000]], grad_fn=<MmBackward>)
# tensor([[-203908.1562]], grad_fn=<MmBackward>)
# tensor([[861789.0625]], grad_fn=<MmBackward>)
# tensor([[-204050.0938]], grad_fn=<MmBackward>)
# tensor([[861982.0625]], grad_fn=<MmBackward>)
# tensor([[-203849.5781]], grad_fn=<MmBackward>)
# tensor([[861745.7500]], grad_fn=<MmBackward>)
# tensor([[-204037.8750]], grad_fn=<MmBackward>)
# tensor([[861729.1875]], grad_fn=<MmBackward>)
# tensor([[-204241.1250]], grad_fn=<MmBackward>)
# tensor([[861809.3750]], grad_fn=<MmBackward>)
# tensor([[-204001.2500]], grad_fn=<MmBackward>)
# tensor([[861440.3750]], grad_fn=<MmBackward>)
# tensor([[-203869.8906]], grad_fn=<MmBackward>)
# tensor([[861949.5625]], grad_fn=<MmBackward>)
# tensor([[-204262.2812]], grad_fn=<MmBackward>)
# tensor([[861583.1875]], grad_fn=<MmBackward>)
# tensor([[-204039.9688]], grad_fn=<MmBackward>)
# tensor([[861771.]], grad_fn=<MmBackward>)
# tensor([[-203624.4375]], grad_fn=<MmBackward>)
# tensor([[861520.6250]], grad_fn=<MmBackward>)
# tensor([[-204027.4062]], grad_fn=<MmBackward>)
# tensor([[861783.7500]], grad_fn=<MmBackward>)
# tensor([[-204185.7500]], grad_fn=<MmBackward>)
# tensor([[861740.]], grad_fn=<MmBackward>)
# tensor([[-1066979.8750]], grad_fn=<MmBackward>)
# tensor([[-52235.7266]], grad_fn=<MmBackward>)
# tensor([[-1067099.5000]], grad_fn=<MmBackward>)
# tensor([[-52793.9023]], grad_fn=<MmBackward>)
# tensor([[-1067229.2500]], grad_fn=<MmBackward>)
# tensor([[-52451.4766]], grad_fn=<MmBackward>)
# tensor([[-1067574.]], grad_fn=<MmBackward>)
# tensor([[-52697.7227]], grad_fn=<MmBackward>)
# tensor([[-1066979.1250]], grad_fn=<MmBackward>)
# tensor([[-52655.6016]], grad_fn=<MmBackward>)
# tensor([[-1066984.]], grad_fn=<MmBackward>)
# tensor([[-53136.0391]], grad_fn=<MmBackward>)
# tensor([[-1067379.8750]], grad_fn=<MmBackward>)
# tensor([[-52416.9023]], grad_fn=<MmBackward>)
# tensor([[-1067486.3750]], grad_fn=<MmBackward>)
# tensor([[-52807.7539]], grad_fn=<MmBackward>)
# tensor([[-1067311.]], grad_fn=<MmBackward>)
# tensor([[-52777.7422]], grad_fn=<MmBackward>)
# tensor([[-1067254.7500]], grad_fn=<MmBackward>)
# tensor([[-52517.3320]], grad_fn=<MmBackward>)
# tensor([[-1067168.2500]], grad_fn=<MmBackward>)
# tensor([[-52490.8047]], grad_fn=<MmBackward>)
# tensor([[-1067402.2500]], grad_fn=<MmBackward>)
# tensor([[-52375.4531]], grad_fn=<MmBackward>)
# tensor([[-1067519.7500]], grad_fn=<MmBackward>)
# tensor([[-52551.8906]], grad_fn=<MmBackward>)
# tensor([[-1067443.1250]], grad_fn=<MmBackward>)
# tensor([[-52389.5781]], grad_fn=<MmBackward>)
# tensor([[-1067652.2500]], grad_fn=<MmBackward>)
# tensor([[-52737.0625]], grad_fn=<MmBackward>)
# tensor([[-1067740.7500]], grad_fn=<MmBackward>)
# tensor([[-52878.8828]], grad_fn=<MmBackward>)
# tensor([[-1067360.1250]], grad_fn=<MmBackward>)
# tensor([[-52312.3320]], grad_fn=<MmBackward>)
# tensor([[-1067250.7500]], grad_fn=<MmBackward>)
# tensor([[-52657.2031]], grad_fn=<MmBackward>)
# tensor([[-1067429.6250]], grad_fn=<MmBackward>)
# tensor([[-52444.0742]], grad_fn=<MmBackward>)
# tensor([[-1067033.5000]], grad_fn=<MmBackward>)
# tensor([[-52541.0859]], grad_fn=<MmBackward>)
# tensor([[-1067356.8750]], grad_fn=<MmBackward>)
# tensor([[-52454.6289]], grad_fn=<MmBackward>)
# tensor([[-1067115.7500]], grad_fn=<MmBackward>)
# tensor([[-52366.7422]], grad_fn=<MmBackward>)
# tensor([[-1066737.7500]], grad_fn=<MmBackward>)
# tensor([[-52810.0742]], grad_fn=<MmBackward>)
# tensor([[-1067223.7500]], grad_fn=<MmBackward>)
# tensor([[-52847.0742]], grad_fn=<MmBackward>)
# tensor([[-1067865.6250]], grad_fn=<MmBackward>)
# tensor([[-52410.5586]], grad_fn=<MmBackward>)
# tensor([[-1067290.5000]], grad_fn=<MmBackward>)
# tensor([[-53236.4102]], grad_fn=<MmBackward>)
# tensor([[-1067345.1250]], grad_fn=<MmBackward>)
# tensor([[-52850.9102]], grad_fn=<MmBackward>)
# tensor([[-1067697.]], grad_fn=<MmBackward>)
# tensor([[-52164.1133]], grad_fn=<MmBackward>)
# tensor([[-1067509.2500]], grad_fn=<MmBackward>)
# tensor([[-52566.1445]], grad_fn=<MmBackward>)
# ...
# tensor([[861229.5000]], grad_fn=<MmBackward>)
# tensor([[-204051.3125]], grad_fn=<MmBackward>)
# tensor([[861862.5625]], grad_fn=<MmBackward>)
# tensor([[-204164.0625]], grad_fn=<MmBackward>)
# tensor([[861492.6875]], grad_fn=<MmBackward>)
# tensor([[-204038.0156]], grad_fn=<MmBackward>)
# tensor([[861533.5625]], grad_fn=<MmBackward>)
# tensor([[-204010.7344]], grad_fn=<MmBackward>)
# tensor([[861777.5000]], grad_fn=<MmBackward>)
# tensor([[-203881.1094]], grad_fn=<MmBackward>)
# tensor([[861758.]], grad_fn=<MmBackward>)
# tensor([[-204062.7500]], grad_fn=<MmBackward>)
# tensor([[861870.8750]], grad_fn=<MmBackward>)
# tensor([[-204247.1250]], grad_fn=<MmBackward>)
# tensor([[861702.3750]], grad_fn=<MmBackward>)
# tensor([[-204144.5625]], grad_fn=<MmBackward>)
# tensor([[861871.9375]], grad_fn=<MmBackward>)
# tensor([[-204361.0781]], grad_fn=<MmBackward>)
# tensor([[861561.2500]], grad_fn=<MmBackward>)
# tensor([[-204405.2656]], grad_fn=<MmBackward>)
# tensor([[861424.7500]], grad_fn=<MmBackward>)
# tensor([[-204047.2500]], grad_fn=<MmBackward>)
# tensor([[861949.8125]], grad_fn=<MmBackward>)
# tensor([[-203917.1875]], grad_fn=<MmBackward>)
# tensor([[861600.5625]], grad_fn=<MmBackward>)
# tensor([[-204127.6719]], grad_fn=<MmBackward>)
# tensor([[861802.6875]], grad_fn=<MmBackward>)
# tensor([[-203770.6250]], grad_fn=<MmBackward>)
# tensor([[861672.2500]], grad_fn=<MmBackward>)
# tensor([[-204125.9219]], grad_fn=<MmBackward>)
# tensor([[861792.7500]], grad_fn=<MmBackward>)
# tensor([[-203831.6406]], grad_fn=<MmBackward>)
# tensor([[861865.4375]], grad_fn=<MmBackward>)
# tensor([[-203480.8438]], grad_fn=<MmBackward>)
# tensor([[861448.1875]], grad_fn=<MmBackward>)
# tensor([[-203947.0312]], grad_fn=<MmBackward>)
# tensor([[861471.]], grad_fn=<MmBackward>)
# tensor([[-204564.5000]], grad_fn=<MmBackward>)
# tensor([[861810.6875]], grad_fn=<MmBackward>)
# tensor([[-204007.1406]], grad_fn=<MmBackward>)
# tensor([[861077.5000]], grad_fn=<MmBackward>)
# tensor([[-204140.4219]], grad_fn=<MmBackward>)
# tensor([[861431.8750]], grad_fn=<MmBackward>)
# tensor([[-204370.1875]], grad_fn=<MmBackward>)
# tensor([[862101.1250]], grad_fn=<MmBackward>)
# tensor([[-204220.5156]], grad_fn=<MmBackward>)
# tensor([[861695.9375]], grad_fn=<MmBackward>)
# tensor([[-203883.3438]], grad_fn=<MmBackward>)
# tensor([[861720.8125]], grad_fn=<MmBackward>)
# tensor([[-204370.6250]], grad_fn=<MmBackward>)
# tensor([[861913.0625]], grad_fn=<MmBackward>)
# tensor([[-204001.4688]], grad_fn=<MmBackward>)
# tensor([[861733.2500]], grad_fn=<MmBackward>)
# tensor([[-204041.7344]], grad_fn=<MmBackward>)
# tensor([[861694.9375]], grad_fn=<MmBackward>)
# tensor([[-204182.2344]], grad_fn=<MmBackward>)
# tensor([[861886.9375]], grad_fn=<MmBackward>)
# tensor([[-203983.5625]], grad_fn=<MmBackward>)
# tensor([[861649.8750]], grad_fn=<MmBackward>)
# tensor([[-204172.9531]], grad_fn=<MmBackward>)
# tensor([[861633.6875]], grad_fn=<MmBackward>)
# tensor([[-204374.5625]], grad_fn=<MmBackward>)
# tensor([[861713.3750]], grad_fn=<MmBackward>)
# tensor([[-204135.6406]], grad_fn=<MmBackward>)
# tensor([[861345.]], grad_fn=<MmBackward>)
# tensor([[-204003.5156]], grad_fn=<MmBackward>)
# tensor([[861855.7500]], grad_fn=<MmBackward>)
# tensor([[-204396.8750]], grad_fn=<MmBackward>)
# tensor([[861489.]], grad_fn=<MmBackward>)
# tensor([[-204175.2344]], grad_fn=<MmBackward>)
# tensor([[861676.2500]], grad_fn=<MmBackward>)
# tensor([[-203758.2031]], grad_fn=<MmBackward>)
# tensor([[861426.5000]], grad_fn=<MmBackward>)
# tensor([[-204160.1406]], grad_fn=<MmBackward>)
# tensor([[861688.8125]], grad_fn=<MmBackward>)
# tensor([[-204321.6406]], grad_fn=<MmBackward>)
# tensor([[861644.9375]], grad_fn=<MmBackward>)
# tensor([[-1066617.7500]], grad_fn=<MmBackward>)
# tensor([[-51886.7930]], grad_fn=<MmBackward>)
# tensor([[-1066736.7500]], grad_fn=<MmBackward>)
# tensor([[-52446.0938]], grad_fn=<MmBackward>)
# tensor([[-1066867.1250]], grad_fn=<MmBackward>)
# tensor([[-52102.5625]], grad_fn=<MmBackward>)
# tensor([[-1067212.7500]], grad_fn=<MmBackward>)
# tensor([[-52348.4219]], grad_fn=<MmBackward>)
# tensor([[-1066617.3750]], grad_fn=<MmBackward>)
# tensor([[-52306.5664]], grad_fn=<MmBackward>)
# tensor([[-1066623.6250]], grad_fn=<MmBackward>)
# tensor([[-52787.4219]], grad_fn=<MmBackward>)
# tensor([[-1067015.2500]], grad_fn=<MmBackward>)
# tensor([[-52068.9258]], grad_fn=<MmBackward>)
# tensor([[-1067124.3750]], grad_fn=<MmBackward>)
# tensor([[-52459.4336]], grad_fn=<MmBackward>)
# tensor([[-1066948.8750]], grad_fn=<MmBackward>)
# tensor([[-52429.0898]], grad_fn=<MmBackward>)
# tensor([[-1066891.5000]], grad_fn=<MmBackward>)
# tensor([[-52168.4688]], grad_fn=<MmBackward>)
# tensor([[-1066806.5000]], grad_fn=<MmBackward>)
# tensor([[-52142.8008]], grad_fn=<MmBackward>)
# tensor([[-1067041.5000]], grad_fn=<MmBackward>)
# tensor([[-52026.5703]], grad_fn=<MmBackward>)
# tensor([[-1067157.7500]], grad_fn=<MmBackward>)
# tensor([[-52202.9258]], grad_fn=<MmBackward>)
# tensor([[-1067080.5000]], grad_fn=<MmBackward>)
# tensor([[-52041.9766]], grad_fn=<MmBackward>)
# tensor([[-1067289.8750]], grad_fn=<MmBackward>)
# tensor([[-52387.6719]], grad_fn=<MmBackward>)
# tensor([[-1067381.1250]], grad_fn=<MmBackward>)
# tensor([[-52529.6133]], grad_fn=<MmBackward>)
# tensor([[-1066998.5000]], grad_fn=<MmBackward>)
# tensor([[-51962.7109]], grad_fn=<MmBackward>)
# tensor([[-1066889.8750]], grad_fn=<MmBackward>)
# tensor([[-52306.7812]], grad_fn=<MmBackward>)
# tensor([[-1067068.2500]], grad_fn=<MmBackward>)
# tensor([[-52095.1289]], grad_fn=<MmBackward>)
# tensor([[-1066672.5000]], grad_fn=<MmBackward>)
# tensor([[-52192.6875]], grad_fn=<MmBackward>)
# tensor([[-1066995.3750]], grad_fn=<MmBackward>)
# tensor([[-52106.2148]], grad_fn=<MmBackward>)
# tensor([[-1066753.5000]], grad_fn=<MmBackward>)
# tensor([[-52017.7148]], grad_fn=<MmBackward>)
# tensor([[-1066374.1250]], grad_fn=<MmBackward>)
# tensor([[-52462.3477]], grad_fn=<MmBackward>)
# tensor([[-1066859.6250]], grad_fn=<MmBackward>)
# tensor([[-52499.6133]], grad_fn=<MmBackward>)
# tensor([[-1067502.6250]], grad_fn=<MmBackward>)
# tensor([[-52061.0781]], grad_fn=<MmBackward>)
# tensor([[-1066928.]], grad_fn=<MmBackward>)
# tensor([[-52888.4961]], grad_fn=<MmBackward>)
# tensor([[-1066982.8750]], grad_fn=<MmBackward>)
# tensor([[-52503.7422]], grad_fn=<MmBackward>)
# tensor([[-1067335.2500]], grad_fn=<MmBackward>)
# tensor([[-51814.8398]], grad_fn=<MmBackward>)
# tensor([[-1067148.5000]], grad_fn=<MmBackward>)
# tensor([[-52217.0430]], grad_fn=<MmBackward>)
# tensor([[-1066824.7500]], grad_fn=<MmBackward>)
# tensor([[-52182.6328]], grad_fn=<MmBackward>)
# tensor([[-1067272.5000]], grad_fn=<MmBackward>)
# tensor([[-51998.9062]], grad_fn=<MmBackward>)
# tensor([[-1066913.2500]], grad_fn=<MmBackward>)
# tensor([[-52183.7969]], grad_fn=<MmBackward>)
# tensor([[-1066967.8750]], grad_fn=<MmBackward>)
# tensor([[-52214.4219]], grad_fn=<MmBackward>)
# tensor([[-1067104.3750]], grad_fn=<MmBackward>)
# tensor([[-52044.2266]], grad_fn=<MmBackward>)
# tensor([[-1066936.3750]], grad_fn=<MmBackward>)
# tensor([[-52294.4492]], grad_fn=<MmBackward>)
# tensor([[-1067129.5000]], grad_fn=<MmBackward>)
# tensor([[-52237.4844]], grad_fn=<MmBackward>)
# tensor([[-1067313.6250]], grad_fn=<MmBackward>)
# tensor([[-52175.8008]], grad_fn=<MmBackward>)
# tensor([[-1067134.3750]], grad_fn=<MmBackward>)
# tensor([[-52606.5312]], grad_fn=<MmBackward>)
# tensor([[-1066971.2500]], grad_fn=<MmBackward>)
# tensor([[-52071.6328]], grad_fn=<MmBackward>)
# tensor([[-1067336.5000]], grad_fn=<MmBackward>)
# tensor([[-52460.6484]], grad_fn=<MmBackward>)
# tensor([[-1067106.8750]], grad_fn=<MmBackward>)
# tensor([[-52235.4023]], grad_fn=<MmBackward>)
# tensor([[-1066619.2500]], grad_fn=<MmBackward>)
# tensor([[-52549.1914]], grad_fn=<MmBackward>)
# tensor([[-1067105.2500]], grad_fn=<MmBackward>)
# tensor([[-52293.3086]], grad_fn=<MmBackward>)
# tensor([[-1067339.1250]], grad_fn=<MmBackward>)
# tensor([[-52197.2344]], grad_fn=<MmBackward>)
# tensor([[-203621.5938]], grad_fn=<MmBackward>)
# tensor([[862091.9375]], grad_fn=<MmBackward>)
# tensor([[-203764.1250]], grad_fn=<MmBackward>)
# tensor([[861577.0625]], grad_fn=<MmBackward>)
# tensor([[-203816.1562]], grad_fn=<MmBackward>)
# tensor([[861897.7500]], grad_fn=<MmBackward>)
# tensor([[-204190.6875]], grad_fn=<MmBackward>)
# tensor([[861657.0625]], grad_fn=<MmBackward>)
# tensor([[-203667.1875]], grad_fn=<MmBackward>)
# tensor([[861679.7500]], grad_fn=<MmBackward>)
# tensor([[-203662.9375]], grad_fn=<MmBackward>)
# tensor([[861314.7500]], grad_fn=<MmBackward>)
# tensor([[-203971.4219]], grad_fn=<MmBackward>)
# tensor([[861948.]], grad_fn=<MmBackward>)
# tensor([[-204083.2812]], grad_fn=<MmBackward>)
# tensor([[861578.1250]], grad_fn=<MmBackward>)
# tensor([[-203957.8906]], grad_fn=<MmBackward>)
# tensor([[861618.3125]], grad_fn=<MmBackward>)
# tensor([[-203930.8125]], grad_fn=<MmBackward>)
# tensor([[861864.2500]], grad_fn=<MmBackward>)
# tensor([[-203801.5312]], grad_fn=<MmBackward>)
# tensor([[861844.1875]], grad_fn=<MmBackward>)
# tensor([[-203981.5312]], grad_fn=<MmBackward>)
# tensor([[861957.1250]], grad_fn=<MmBackward>)
# tensor([[-204166.4375]], grad_fn=<MmBackward>)
# tensor([[861787.0625]], grad_fn=<MmBackward>)
# tensor([[-204064.3281]], grad_fn=<MmBackward>)
# tensor([[861957.8125]], grad_fn=<MmBackward>)
# tensor([[-204279.4688]], grad_fn=<MmBackward>)
# tensor([[861646.1250]], grad_fn=<MmBackward>)
# tensor([[-204325.0625]], grad_fn=<MmBackward>)
# tensor([[861509.5000]], grad_fn=<MmBackward>)
# tensor([[-203966.4844]], grad_fn=<MmBackward>)
# tensor([[862035.4375]], grad_fn=<MmBackward>)
# tensor([[-203835.1562]], grad_fn=<MmBackward>)
# tensor([[861685.6875]], grad_fn=<MmBackward>)
# tensor([[-204047.9062]], grad_fn=<MmBackward>)
# tensor([[861888.5625]], grad_fn=<MmBackward>)
# tensor([[-203690.9375]], grad_fn=<MmBackward>)
# tensor([[861758.0625]], grad_fn=<MmBackward>)
# tensor([[-204044.9062]], grad_fn=<MmBackward>)
# tensor([[861878.3750]], grad_fn=<MmBackward>)
# tensor([[-203751.4219]], grad_fn=<MmBackward>)
# tensor([[861950.1875]], grad_fn=<MmBackward>)
# tensor([[-203399.2500]], grad_fn=<MmBackward>)
# tensor([[861534.6250]], grad_fn=<MmBackward>)
# tensor([[-203865.5156]], grad_fn=<MmBackward>)
# tensor([[861557.1875]], grad_fn=<MmBackward>)
# tensor([[-204483.7031]], grad_fn=<MmBackward>)
# tensor([[861897.1250]], grad_fn=<MmBackward>)
# tensor([[-203926.5781]], grad_fn=<MmBackward>)
# tensor([[861163.1875]], grad_fn=<MmBackward>)
# tensor([[-204061.3906]], grad_fn=<MmBackward>)
# tensor([[861518.3125]], grad_fn=<MmBackward>)
# tensor([[-204289.1406]], grad_fn=<MmBackward>)
# tensor([[862187.1250]], grad_fn=<MmBackward>)
# tensor([[-204140.5781]], grad_fn=<MmBackward>)
# tensor([[861781.3125]], grad_fn=<MmBackward>)
# tensor([[-203803.1094]], grad_fn=<MmBackward>)
# tensor([[861807.6250]], grad_fn=<MmBackward>)
# tensor([[-204290.9844]], grad_fn=<MmBackward>)
# tensor([[861998.2500]], grad_fn=<MmBackward>)
# tensor([[-203920.9219]], grad_fn=<MmBackward>)
# tensor([[861818.9375]], grad_fn=<MmBackward>)
# tensor([[-203960.3594]], grad_fn=<MmBackward>)
# tensor([[861779.7500]], grad_fn=<MmBackward>)
# tensor([[-204103.0312]], grad_fn=<MmBackward>)
# tensor([[861972.]], grad_fn=<MmBackward>)
# tensor([[-203903.7969]], grad_fn=<MmBackward>)
# tensor([[861736.6250]], grad_fn=<MmBackward>)
# tensor([[-204091.1250]], grad_fn=<MmBackward>)
# tensor([[861719.5625]], grad_fn=<MmBackward>)
# tensor([[-204294.0781]], grad_fn=<MmBackward>)
# tensor([[861801.5000]], grad_fn=<MmBackward>)
# tensor([[-204055.0469]], grad_fn=<MmBackward>)
# tensor([[861430.6875]], grad_fn=<MmBackward>)
# tensor([[-203922.8438]], grad_fn=<MmBackward>)
# tensor([[861940.1875]], grad_fn=<MmBackward>)
# tensor([[-204315.9688]], grad_fn=<MmBackward>)
# tensor([[861574.8125]], grad_fn=<MmBackward>)
# tensor([[-204093.9688]], grad_fn=<MmBackward>)
# tensor([[861761.3750]], grad_fn=<MmBackward>)
# tensor([[-203678.7344]], grad_fn=<MmBackward>)
# tensor([[861512.1875]], grad_fn=<MmBackward>)
# tensor([[-204081.3281]], grad_fn=<MmBackward>)
# tensor([[861773.7500]], grad_fn=<MmBackward>)
# tensor([[-204240.6562]], grad_fn=<MmBackward>)
# tensor([[861731.1250]], grad_fn=<MmBackward>)
# tensor([[-1066953.]], grad_fn=<MmBackward>)
# tensor([[-52190.6289]], grad_fn=<MmBackward>)
# tensor([[-1067073.3750]], grad_fn=<MmBackward>)
# tensor([[-52749.8750]], grad_fn=<MmBackward>)
# tensor([[-1067202.3750]], grad_fn=<MmBackward>)
# tensor([[-52405.1914]], grad_fn=<MmBackward>)
# tensor([[-1067549.3750]], grad_fn=<MmBackward>)
# tensor([[-52652.1797]], grad_fn=<MmBackward>)
# tensor([[-1066952.6250]], grad_fn=<MmBackward>)
# tensor([[-52611.0195]], grad_fn=<MmBackward>)
# tensor([[-1066958.2500]], grad_fn=<MmBackward>)
# tensor([[-53091.3047]], grad_fn=<MmBackward>)
# tensor([[-1067353.]], grad_fn=<MmBackward>)
# tensor([[-52373.4922]], grad_fn=<MmBackward>)
# tensor([[-1067460.7500]], grad_fn=<MmBackward>)
# tensor([[-52763.6797]], grad_fn=<MmBackward>)
# tensor([[-1067285.6250]], grad_fn=<MmBackward>)
# tensor([[-52731.8281]], grad_fn=<MmBackward>)
# tensor([[-1067228.]], grad_fn=<MmBackward>)
# tensor([[-52471.8750]], grad_fn=<MmBackward>)
# tensor([[-1067140.]], grad_fn=<MmBackward>)
# tensor([[-52446.6367]], grad_fn=<MmBackward>)
# tensor([[-1067375.5000]], grad_fn=<MmBackward>)
# tensor([[-52330.6406]], grad_fn=<MmBackward>)
# tensor([[-1067493.2500]], grad_fn=<MmBackward>)
# tensor([[-52506.9102]], grad_fn=<MmBackward>)
# tensor([[-1067417.6250]], grad_fn=<MmBackward>)
# tensor([[-52346.1758]], grad_fn=<MmBackward>)
# tensor([[-1067624.8750]], grad_fn=<MmBackward>)
# tensor([[-52690.4141]], grad_fn=<MmBackward>)
# tensor([[-1067715.8750]], grad_fn=<MmBackward>)
# tensor([[-52830.9336]], grad_fn=<MmBackward>)
# tensor([[-1067334.]], grad_fn=<MmBackward>)
# tensor([[-52266.8047]], grad_fn=<MmBackward>)
# tensor([[-1067224.6250]], grad_fn=<MmBackward>)
# tensor([[-52611.6289]], grad_fn=<MmBackward>)
# tensor([[-1067404.]], grad_fn=<MmBackward>)
# tensor([[-52398.6250]], grad_fn=<MmBackward>)
# tensor([[-1067007.2500]], grad_fn=<MmBackward>)
# tensor([[-52494.7383]], grad_fn=<MmBackward>)
# tensor([[-1067329.8750]], grad_fn=<MmBackward>)
# tensor([[-52409.4727]], grad_fn=<MmBackward>)
# tensor([[-1067087.3750]], grad_fn=<MmBackward>)
# tensor([[-52320.2578]], grad_fn=<MmBackward>)
# tensor([[-1066710.5000]], grad_fn=<MmBackward>)
# tensor([[-52764.1641]], grad_fn=<MmBackward>)
# tensor([[-1067195.8750]], grad_fn=<MmBackward>)
# tensor([[-52802.6289]], grad_fn=<MmBackward>)
# tensor([[-1067837.3750]], grad_fn=<MmBackward>)
# tensor([[-52364.1758]], grad_fn=<MmBackward>)
# tensor([[-1067264.]], grad_fn=<MmBackward>)
# tensor([[-53190.9258]], grad_fn=<MmBackward>)
# tensor([[-1067317.6250]], grad_fn=<MmBackward>)
# tensor([[-52805.8203]], grad_fn=<MmBackward>)
# tensor([[-1067671.7500]], grad_fn=<MmBackward>)
# tensor([[-52118.5078]], grad_fn=<MmBackward>)
# tensor([[-1067485.1250]], grad_fn=<MmBackward>)
# tensor([[-52520.6719]], grad_fn=<MmBackward>)
# tensor([[-1067162.2500]], grad_fn=<MmBackward>)
# tensor([[-52485.]], grad_fn=<MmBackward>)
# tensor([[-1067607.8750]], grad_fn=<MmBackward>)
# tensor([[-52303.2578]], grad_fn=<MmBackward>)
# tensor([[-1067250.7500]], grad_fn=<MmBackward>)
# tensor([[-52487.8438]], grad_fn=<MmBackward>)
# tensor([[-1067304.8750]], grad_fn=<MmBackward>)
# tensor([[-52518.7891]], grad_fn=<MmBackward>)
# tensor([[-1067441.1250]], grad_fn=<MmBackward>)
# tensor([[-52346.7188]], grad_fn=<MmBackward>)
# tensor([[-1067272.1250]], grad_fn=<MmBackward>)
# tensor([[-52599.2070]], grad_fn=<MmBackward>)
# tensor([[-1067463.6250]], grad_fn=<MmBackward>)
# tensor([[-52541.5547]], grad_fn=<MmBackward>)
# tensor([[-1067648.3750]], grad_fn=<MmBackward>)
# tensor([[-52478.7852]], grad_fn=<MmBackward>)
# tensor([[-1067470.2500]], grad_fn=<MmBackward>)
# tensor([[-52909.3672]], grad_fn=<MmBackward>)
# tensor([[-1067307.3750]], grad_fn=<MmBackward>)
# tensor([[-52377.7266]], grad_fn=<MmBackward>)
# tensor([[-1067671.6250]], grad_fn=<MmBackward>)
# tensor([[-52763.4648]], grad_fn=<MmBackward>)
# tensor([[-1067444.5000]], grad_fn=<MmBackward>)
# tensor([[-52538.9609]], grad_fn=<MmBackward>)
# tensor([[-1066954.5000]], grad_fn=<MmBackward>)
# tensor([[-52852.8633]], grad_fn=<MmBackward>)
# tensor([[-1067440.1250]], grad_fn=<MmBackward>)
# tensor([[-52596.9102]], grad_fn=<MmBackward>)
# tensor([[-1067672.8750]], grad_fn=<MmBackward>)
# tensor([[-52501.4375]], grad_fn=<MmBackward>)
# V_x torch.Size([1, 256, 88]) A_2 torch.Size([88, 88])
# V_2 torch.Size([1, 256, 88])

# %%
out
# Out:
# tensor([[[[nan]]]], grad_fn=<MkldnnConvolutionBackward>)
